# %%
d = {"key": "value", "key1": "value1"}

# %%
d['key']
# Out:
# 'value'

# %%
import box 
print(box.__file__)
print(dir(box))
# Out:
# c:\Users\Nitin\TEXT-SUMMARISER\venv\Lib\site-packages\box\__init__.py
# ['Box', 'BoxError', 'BoxKeyError', 'BoxList', 'ConfigBox', 'SBox', '__all__', '__author__', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__path__', '__spec__', '__version__', 'box', 'box_from_file', 'box_list', 'config_box', 'converters', 'exceptions', 'from_file', 'shorthand_box']

# %%
from box import ConfigBox

# %%
d2 = ConfigBox({"key": "value", "key1": "value1"})
d2
# Out:
# <ConfigBox: {'key': 'value', 'key1': 'value1'}>

# %%
d2.key
# Out:
# 'value'

# %%
def get_product(x: int, y: int) -> int:
    return x * y

# %%
get_product(x = 2, y = 4)
# Out:
# 8

# %%
get_product(x = 2, y = "4")
# Out:
# '44'

# %%
from ensure import ensure_annotations

# %%
def get_product(x: int, y: int) -> int:
    return x * y

# %%
get_product(x = 2, y = 4)
# Out:
# 8
